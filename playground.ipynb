# %% [markdown]
# # Imaginary Soundscape Demo Code

# %% [markdown]
# ## Before you try ...

# %% [markdown]
# - please download this zipped data file and unzip it into the same directory as this notebook:
# https://github.com/Kajiyu/ImaginarySoundscapeDemo/releases/download/v1.0.0/data.zip

# %% [markdown]
# ## Additional Information

# %% [markdown]
# ### References
#
# - Imaginary Soundscape: http://imaginarysoundscape2.qosmo.jp/
# - the original demo (Chrome and Firefox are only available.) : http://imaginarysoundscape.qosmo.jp/
# - the original paper: https://nips2017creativity.github.io/doc/Imaginary_Soundscape.pdf

# %% [markdown]
# ### Model
# ![Model](https://github.com/Kajiyu/ImaginarySoundscapeDemo/raw/master/assets/model.jpg)

# %% [markdown]
# ### Other references
# - Our model is based on MIT's SoundNet: http://soundnet.csail.mit.edu/

# %% [markdown]
# ## Dependencies

# %%
import warnings
warnings.filterwarnings('ignore')
import os, sys
import shutil
import glob
import json
import collections
import tensorflow as tf
import numpy as np
import librosa
import random
from scipy.stats import entropy

import keras
from keras.models import Model, load_model
import keras.backend as K
from keras.applications.mobilenet import MobileNet
##from keras.preprocessing import image
from keras.utils import load_img, img_to_array
from IPython.display import Audio, Image, display_jpeg, display

# %%
pip install librosa
# Out:
# Requirement already satisfied: librosa in c:\users\2469117b\.conda\envs\ai_for_the_arts_environment\lib\site-packages (0.10.1)
# Requirement already satisfied: audioread>=2.1.9 in c:\users\2469117b\.conda\envs\ai_for_the_arts_environment\lib\site-packages (from librosa) (3.0.1)
# Requirement already satisfied: numpy!=1.22.0,!=1.22.1,!=1.22.2,>=1.20.3 in c:\users\2469117b\.conda\envs\ai_for_the_arts_environment\lib\site-packages (from librosa) (1.26.0)
# Requirement already satisfied: scipy>=1.2.0 in c:\users\2469117b\.conda\envs\ai_for_the_arts_environment\lib\site-packages (from librosa) (1.11.3)
# Requirement already satisfied: scikit-learn>=0.20.0 in c:\users\2469117b\.conda\envs\ai_for_the_arts_environment\lib\site-packages (from librosa) (1.3.0)
# Requirement already satisfied: joblib>=0.14 in c:\users\2469117b\.conda\envs\ai_for_the_arts_environment\lib\site-packages (from librosa) (1.2.0)
# Requirement already satisfied: decorator>=4.3.0 in c:\users\2469117b\.conda\envs\ai_for_the_arts_environment\lib\site-packages (from librosa) (5.1.1)
# Requirement already satisfied: numba>=0.51.0 in c:\users\2469117b\.conda\envs\ai_for_the_arts_environment\lib\site-packages (from librosa) (0.59.0)
# Requirement already satisfied: soundfile>=0.12.1 in c:\users\2469117b\.conda\envs\ai_for_the_arts_environment\lib\site-packages (from librosa) (0.12.1)
# Requirement already satisfied: pooch>=1.0 in c:\users\2469117b\.conda\envs\ai_for_the_arts_environment\lib\site-packages (from librosa) (1.8.1)
# Requirement already satisfied: soxr>=0.3.2 in c:\users\2469117b\.conda\envs\ai_for_the_arts_environment\lib\site-packages (from librosa) (0.3.7)
# Requirement already satisfied: typing-extensions>=4.1.1 in c:\users\2469117b\.conda\envs\ai_for_the_arts_environment\lib\site-packages (from librosa) (4.7.1)
# Requirement already satisfied: lazy-loader>=0.1 in c:\users\2469117b\.conda\envs\ai_for_the_arts_environment\lib\site-packages (from librosa) (0.3)
# Requirement already satisfied: msgpack>=1.0 in c:\users\2469117b\.conda\envs\ai_for_the_arts_environment\lib\site-packages (from librosa) (1.0.8)
# Requirement already satisfied: llvmlite<0.43,>=0.42.0dev0 in c:\users\2469117b\.conda\envs\ai_for_the_arts_environment\lib\site-packages (from numba>=0.51.0->librosa) (0.42.0)
# Requirement already satisfied: platformdirs>=2.5.0 in c:\users\2469117b\.conda\envs\ai_for_the_arts_environment\lib\site-packages (from pooch>=1.0->librosa) (3.10.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\2469117b\.conda\envs\ai_for_the_arts_environment\lib\site-packages (from pooch>=1.0->librosa) (23.1)
# Requirement already satisfied: requests>=2.19.0 in c:\users\2469117b\.conda\envs\ai_for_the_arts_environment\lib\site-packages (from pooch>=1.0->librosa) (2.31.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\2469117b\.conda\envs\ai_for_the_arts_environment\lib\site-packages (from scikit-learn>=0.20.0->librosa) (2.2.0)
# Requirement already satisfied: cffi>=1.0 in c:\users\2469117b\.conda\envs\ai_for_the_arts_environment\lib\site-packages (from soundfile>=0.12.1->librosa) (1.15.1)
# Requirement already satisfied: pycparser in c:\users\2469117b\.conda\envs\ai_for_the_arts_environment\lib\site-packages (from cffi>=1.0->soundfile>=0.12.1->librosa) (2.21)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\2469117b\.conda\envs\ai_for_the_arts_environment\lib\site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\2469117b\.conda\envs\ai_for_the_arts_environment\lib\site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\2469117b\.conda\envs\ai_for_the_arts_environment\lib\site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\2469117b\.conda\envs\ai_for_the_arts_environment\lib\site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (2023.7.22)
# Note: you may need to restart the kernel to use updated packages.

# %%
import librosa.display

# %% [markdown]
# ## Function Definitions

# %%
def preprocess_image(x):
    x /= 255.
    x -= 0.5
    x *= 2.
    return x

# %%
def get_image_features(model, filepath):
    img = load_img(filepath, target_size=(224, 224))
    x = img_to_array(img)
    x = np.expand_dims(x, axis=0)
    x = preprocess_image(x)
    preds = model.predict(x)[0]
    return preds

# %%
def get_sound_features(model,filepath):
    x, sr = librosa.load(filepath)
    x = x * 255.0
    x = np.reshape(x, (1, x.shape[0], 1, 1))
    x[x < -255.] = -255.
    x[x > 255.] = 255.
    assert np.max(x) < 256., "It seems this audio contains signal that exceeds 256"
    assert np.min(x) > -256., "It seems this audio contains signal that exceeds -256 " + str(np.min(x)) + " : " + filepath
    _y_pred = model.predict(x)
    feature =  _y_pred[0][0][0][0]
    return feature

# %%
def get_topk_songs(img_feature, song_features, k=3):
    distances = []
    for i in range(len(song_features)):
        distance = entropy(img_feature, song_features[i])
        distances.append(distance)
    topk_indecies = np.argsort(distances)[:k]
    return topk_indecies

# %%
def create_sound_libs(
    soundnet_model,
    query="./data/sound_samples/*.mp3",
    out_json_path="./data/sounds.json",
    out_npy_path='./data/song_features.npy'
):
    mp3_files = glob.glob(query)
    output_dict = {"mp3":[]}
    for i in range(len(mp3_files)):
        x, sr = librosa.load(mp3_files[i])
        if len(x) > 230000:
            output_dict["mp3"].append({"filepath":mp3_files[i], "index":str(i)})
    with open(out_json_path, "w")  as f:
        json.dump(output_dict, f, ensure_ascii=False, indent=4, sort_keys=True, separators=(',', ': '))
    song_features = []
    for item in output_dict["mp3"]:
        i_feature = get_sound_features(soundnet_model,item['filepath'])
        song_features.append(i_feature)
    song_features = np.array(song_features)
    print("Sound npy shape:", song_features.shape)
    np.save(out_npy_path, song_features)
    return (output_dict, song_features)

# %% [markdown]
# # How to

# %% [markdown]
# ## 1. Load SoundNet and ImageNet models

# %%
soundnet = load_model("./data/models/soundnet.hdf5")
imagenet = MobileNet(include_top=True, weights='imagenet') # using MobileNet
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.

# %% [markdown]
# ## 2. Create sound features using SoundNet model

# %% [markdown]
# - npy file: features of sounds pre-calculated by SoundNet
# - json file: including ...
#     - filepath: the path of each sound file
#     - index: the index of each sound file at the npy array

# %%
# create sound features using SoundNet model
(mp3_files, sound_features) = create_sound_libs(soundnet)

print
print("#of mp3 files", len(mp3_files['mp3']))
# Out:
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 240ms/step
# 1/1 [==============================] - 0s 122ms/step
# 1/1 [==============================] - 0s 137ms/step
# 1/1 [==============================] - 0s 88ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 119ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 89ms/step
# 1/1 [==============================] - 0s 119ms/step
# 1/1 [==============================] - 0s 122ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 104ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 129ms/step
# 1/1 [==============================] - 0s 112ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 77ms/step
# 1/1 [==============================] - 0s 121ms/step
# 1/1 [==============================] - 0s 89ms/step
# 1/1 [==============================] - 0s 128ms/step
# 1/1 [==============================] - 0s 113ms/step
# 1/1 [==============================] - 0s 85ms/step
# 1/1 [==============================] - 0s 115ms/step
# 1/1 [==============================] - 0s 184ms/step
# 1/1 [==============================] - 0s 104ms/step
# 1/1 [==============================] - 0s 154ms/step
# 1/1 [==============================] - 0s 123ms/step
# 1/1 [==============================] - 0s 119ms/step
# 1/1 [==============================] - 0s 106ms/step
# 1/1 [==============================] - 0s 126ms/step
# 1/1 [==============================] - 0s 132ms/step
# 1/1 [==============================] - 0s 145ms/step
# 1/1 [==============================] - 0s 145ms/step
# 1/1 [==============================] - 0s 129ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 118ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 126ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 132ms/step
# 1/1 [==============================] - 0s 114ms/step
# 1/1 [==============================] - 0s 144ms/step
# 1/1 [==============================] - 0s 123ms/step
# 1/1 [==============================] - 0s 190ms/step
# 1/1 [==============================] - 0s 118ms/step
# 1/1 [==============================] - 0s 242ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 121ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 157ms/step
# 1/1 [==============================] - 0s 109ms/step
# 1/1 [==============================] - 0s 160ms/step
# 1/1 [==============================] - 0s 126ms/step
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 129ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 126ms/step
# 1/1 [==============================] - 0s 307ms/step
# 1/1 [==============================] - 0s 123ms/step
# 1/1 [==============================] - 0s 136ms/step
# 1/1 [==============================] - 0s 88ms/step
# 1/1 [==============================] - 0s 128ms/step
# 1/1 [==============================] - 0s 143ms/step
# 1/1 [==============================] - 0s 77ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 149ms/step
# 1/1 [==============================] - 0s 173ms/step
# 1/1 [==============================] - 0s 86ms/step
# 1/1 [==============================] - 0s 82ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 128ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 119ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 158ms/step
# 1/1 [==============================] - 0s 107ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 141ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 135ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 108ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 113ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 108ms/step
# 1/1 [==============================] - 0s 127ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 130ms/step
# 1/1 [==============================] - 0s 115ms/step
# 1/1 [==============================] - 0s 162ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 140ms/step
# 1/1 [==============================] - 0s 162ms/step
# 1/1 [==============================] - 0s 161ms/step
# 1/1 [==============================] - 0s 135ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 119ms/step
# 1/1 [==============================] - 0s 168ms/step
# 1/1 [==============================] - 0s 121ms/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 172ms/step
# 1/1 [==============================] - 0s 132ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 123ms/step
# 1/1 [==============================] - 0s 112ms/step
# 1/1 [==============================] - 0s 130ms/step
# 1/1 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 151ms/step
# 1/1 [==============================] - 0s 111ms/step
# 1/1 [==============================] - 0s 113ms/step
# 1/1 [==============================] - 0s 157ms/step
# 1/1 [==============================] - 0s 153ms/step
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 138ms/step
# 1/1 [==============================] - 0s 104ms/step
# 1/1 [==============================] - 0s 132ms/step
# 1/1 [==============================] - 0s 125ms/step
# 1/1 [==============================] - 0s 124ms/step
# 1/1 [==============================] - 0s 142ms/step
# 1/1 [==============================] - 0s 126ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 85ms/step
# 1/1 [==============================] - 0s 125ms/step
# 1/1 [==============================] - 0s 151ms/step
# 1/1 [==============================] - 0s 87ms/step
# 1/1 [==============================] - 0s 81ms/step
# 1/1 [==============================] - 0s 87ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 116ms/step
# 1/1 [==============================] - 0s 132ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 155ms/step
# 1/1 [==============================] - 0s 111ms/step
# 1/1 [==============================] - 0s 111ms/step
# 1/1 [==============================] - 0s 87ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 165ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 166ms/step
# 1/1 [==============================] - 0s 130ms/step
# 1/1 [==============================] - 0s 125ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 145ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 152ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 111ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 123ms/step
# 1/1 [==============================] - 0s 236ms/step
# 1/1 [==============================] - 0s 163ms/step
# 1/1 [==============================] - 0s 175ms/step
# 1/1 [==============================] - 0s 143ms/step
# 1/1 [==============================] - 0s 143ms/step
# 1/1 [==============================] - 0s 128ms/step
# 1/1 [==============================] - 0s 158ms/step
# 1/1 [==============================] - 0s 172ms/step
# 1/1 [==============================] - 0s 131ms/step
# 1/1 [==============================] - 0s 160ms/step
# 1/1 [==============================] - 0s 156ms/step
# 1/1 [==============================] - 0s 206ms/step
# 1/1 [==============================] - 0s 138ms/step
# 1/1 [==============================] - 0s 175ms/step
# 1/1 [==============================] - 0s 215ms/step
# 1/1 [==============================] - 0s 138ms/step
# 1/1 [==============================] - 0s 114ms/step
# 1/1 [==============================] - 0s 138ms/step
# 1/1 [==============================] - 0s 124ms/step
# 1/1 [==============================] - 0s 124ms/step
# 1/1 [==============================] - 0s 127ms/step
# 1/1 [==============================] - 0s 154ms/step
# 1/1 [==============================] - 0s 143ms/step
# 1/1 [==============================] - 0s 123ms/step
# 1/1 [==============================] - 0s 146ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 149ms/step
# 1/1 [==============================] - 0s 147ms/step
# 1/1 [==============================] - 0s 135ms/step
# 1/1 [==============================] - 0s 170ms/step
# 1/1 [==============================] - 0s 104ms/step
# 1/1 [==============================] - 0s 123ms/step
# 1/1 [==============================] - 0s 85ms/step
# 1/1 [==============================] - 0s 150ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 140ms/step
# 1/1 [==============================] - 0s 248ms/step
# 1/1 [==============================] - 0s 107ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 77ms/step
# 1/1 [==============================] - 0s 123ms/step
# 1/1 [==============================] - 0s 134ms/step
# 1/1 [==============================] - 0s 143ms/step
# 1/1 [==============================] - 0s 144ms/step
# 1/1 [==============================] - 0s 138ms/step
# 1/1 [==============================] - 0s 104ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 126ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 119ms/step
# 1/1 [==============================] - 0s 154ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 121ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 151ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 107ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 86ms/step
# 1/1 [==============================] - 0s 139ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 123ms/step
# 1/1 [==============================] - 0s 146ms/step
# 1/1 [==============================] - 0s 181ms/step
# 1/1 [==============================] - 0s 188ms/step
# 1/1 [==============================] - 0s 134ms/step
# 1/1 [==============================] - 0s 116ms/step
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 120ms/step
# 1/1 [==============================] - 0s 131ms/step
# 1/1 [==============================] - 0s 126ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 129ms/step
# 1/1 [==============================] - 0s 173ms/step
# 1/1 [==============================] - 0s 294ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 157ms/step
# 1/1 [==============================] - 0s 133ms/step
# 1/1 [==============================] - 0s 134ms/step
# 1/1 [==============================] - 0s 107ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 149ms/step
# 1/1 [==============================] - 0s 204ms/step
# 1/1 [==============================] - 0s 138ms/step
# 1/1 [==============================] - 0s 139ms/step
# 1/1 [==============================] - 0s 131ms/step
# 1/1 [==============================] - 0s 222ms/step
# 1/1 [==============================] - 0s 133ms/step
# 1/1 [==============================] - 0s 125ms/step
# 1/1 [==============================] - 0s 131ms/step
# 1/1 [==============================] - 0s 126ms/step
# 1/1 [==============================] - 0s 147ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 183ms/step
# Sound npy shape: (268, 1000)
# #of mp3 files 268

# %% [markdown]
# or

# %%
# or, load pre-processed json data
with open("./data/sounds.json") as f:
    mp3_files = json.load(f)
sound_features = np.load("./data/song_features.npy")

# %% [markdown]
# ## 3. Find the best-matched sound files for an input image

# %%
IMG_PATH = "./images/grandpa car.jpg"
display_jpeg(Image(IMG_PATH))

# %%
# Extract image features using ImageNet model(MobileNet)
img_feature = get_image_features(imagenet, IMG_PATH)

# Match the image features and pre-processed sound features,
# then find the topK best matched sound files 
topk_indecies = get_topk_songs(img_feature, sound_features, k=3)
# Out:
# 1/1 [==============================] - 0s 68ms/step

# %%
print("The best-matched sound:")
print

for i in range(3):
    print("Top #", i)
    display(Audio(mp3_files["mp3"][topk_indecies[i]]["filepath"]))
# Out:
# The best-matched sound:
# Top # 0
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
# Top # 1
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
# Top # 2
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
